# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
pd.read_csv('Churn_Modelling.csv', usecols=["CustomerId", "Surname"])
# Out:
#       CustomerId    Surname
# 0       15634602   Hargrave
# 1       15647311       Hill
# 2       15619304       Onio
# 3       15701354       Boni
# 4       15737888   Mitchell
# ...          ...        ...
# 9995    15606229   Obijiaku
# 9996    15569892  Johnstone
# 9997    15584532        Liu
# 9998    15682355  Sabbatini
# 9999    15628319     Walker
#
# [10000 rows x 2 columns]

# %%
pd.read_csv('Churn_Modelling.csv', nrows=100)
# Out:
#     RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602    Hargrave          619    France  Female   42
# 1           2    15647311        Hill          608     Spain  Female   41
# 2           3    15619304        Onio          502    France  Female   42
# 3           4    15701354        Boni          699    France  Female   39
# 4           5    15737888    Mitchell          850     Spain  Female   43
# ..        ...         ...         ...          ...       ...     ...  ...
# 95         96    15699461  Fiorentini          515     Spain    Male   35
# 96         97    15738721      Graham          773     Spain    Male   41
# 97         98    15693683      Yuille          814   Germany    Male   29
# 98         99    15604348      Allard          710     Spain    Male   22
# 99        100    15633059     Fanucci          413    France    Male   34
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df_chunk = df.sample(n=1000)

# %%
df_chunk
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 4972       4973    15612524         Hunt          643   Germany    Male   41
# 9279       9280    15573854  Chukwujekwu          727    France    Male   62
# 997         998    15608114      Manfrin          587     Spain    Male   62
# 322         323    15694408         Lung          749    France    Male   40
# 8705       8706    15804064     Docherty          742    France  Female   35
# ...         ...         ...          ...          ...       ...     ...  ...
# 3530       3531    15623712       Coates          453     Spain  Female   42
# 4297       4298    15778149     Connolly          538     Spain    Male   68
# 4196       4197    15796910         Tsui          625     Spain  Female   57
# 5174       5175    15812594         Ross          791    France    Male   34
# 9142       9143    15663312       Marino          494    France  Female   35
#
# ...

# %%
df_chunk = df.sample(frac=0.1)

# %%
df_chunk
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 7894       7895    15718281             Muir          706   Germany    Male
# 3079       3080    15774727          Monaldo          757   Germany  Female
# 3872       3873    15620123         Christie          605    France    Male
# 7389       7390    15676909           Mishin          667     Spain  Female
# 2922       2923    15705113             P'an          685     Spain    Male
# ...         ...         ...              ...          ...       ...     ...
# 235         236    15772896     Dumetochukwu          763   Germany    Male
# 9803       9804    15776558         Nicholls          673    France    Male
# 7149       7150    15699340           Okorie          680    France    Male
# 874         875    15674840  Chiazagomekpere          645    France  Female
# 6525       6526    15598157        Onyeorulu          728    France    Male
#
# ...

# %%
df['test']= 'pupa'
df['test2']= 'lupa'

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df = df.drop(['test', 'test2'], axis=1)

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['test'] = 'pupa'
df['test2'] = 'lupa'

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.drop(['test', 'test2'], axis=1, inplace=True)

# %%
df = df.drop(['test', 'test2'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = df.drop(['test', 'test2'], axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[df['CustomerId'].isna()]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
df[~df['CustomerId'].isna()]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
missing_index = np.random.randint(10000, size=20)

# %%
missing_index
# Out:
# array([ 229, 4779, 4779, 3083, 5835, 4317,  331,  755, 8716, 1718, 6539,
#        3388, 8325, 3360, 6760, 5662, 9987, 2209,  906, 3496])

# %%
df.loc[missing_index, ['Balance', 'Geography']] = np.nan

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography          19
# Gender              0
# Age                 0
# Tenure              0
# Balance            19
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited              0
# dtype: int64

# %%
df.iloc[missing_index, -1] = np.nan

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography          19
# Gender              0
# Age                 0
# Tenure              0
# Balance            19
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited             19
# dtype: int64

# %%
more_freq = df['Geography'].value_counts().index[0]

# %%
df['Geography'].fillna(value=more_freq, inplace=True)

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                 0
# Tenure              0
# Balance            19
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited             19
# dtype: int64

# %%
avg = df['Balance'].mean()
df['Balance'].fillna(value=avg, inplace=True)

# %%
df.isna().sum()
# Out:
# RowNumber           0
# CustomerId          0
# Surname             0
# CreditScore         0
# Geography           0
# Gender              0
# Age                 0
# Tenure              0
# Balance             0
# NumOfProducts       0
# HasCrCard           0
# IsActiveMember      0
# EstimatedSalary     0
# Exited             19
# dtype: int64

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df[(df['Geography'] == 'France') & (df['Age'] > 30)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 2             3    15619304         Onio          502    France  Female   42
# 3             4    15701354         Boni          699    France  Female   39
# 6             7    15592531     Bartlett          822    France    Male   50
# 8             9    15792365           He          501    France    Male   44
# ...         ...         ...          ...          ...       ...     ...  ...
# 9985       9986    15586914       Nepean          659    France    Male   36
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
#
# ...

# %%
df_filtered = df[(df['Geography'] == 'France') & (df['Age'] > 30)]

# %%
df_filtered = df.query('80000 < Balance < 100000')

# %%
df_filtered['Balance'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[~df['Age'].isin([42, 28])]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 1             2    15647311         Hill          608     Spain  Female   41
# 3             4    15701354         Boni          699    France  Female   39
# 4             5    15737888     Mitchell          850     Spain  Female   43
# 5             6    15574012          Chu          645     Spain    Male   44
# 6             7    15592531     Bartlett          822    France    Male   50
# ...         ...         ...          ...          ...       ...     ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
#
# ...

# %%
df.groupby(['Geography'])['Balance'].sum()
# Out:
# Geography
# France     3.107974e+08
# Germany    3.000158e+08
# Spain      1.526674e+08
# Name: Balance, dtype: float64

# %%
df.groupby(['Geography', 'Gender'])['Balance'].sum()
# Out:
# Geography  Gender
# France     Female    1.363896e+08
#            Male      1.744078e+08
# Germany    Female    1.420103e+08
#            Male      1.580055e+08
# Spain      Female    6.504332e+07
#            Male      8.762411e+07
# Name: Balance, dtype: float64

# %%
df.groupby(['Geography', 'Gender'])['Balance'].agg(['sum', 'mean', 'count'])
# Out:
#                            sum           mean  count
# Geography Gender
# France    Female  1.363896e+08   60402.815425   2258
#           Male    1.744078e+08   63536.537326   2745
# Germany   Female  1.420103e+08  119136.164245   1192
#           Male    1.580055e+08  120247.706119   1314
# Spain     Female  6.504332e+07   59782.460202   1088
#           Male    8.762411e+07   63312.220173   1384
